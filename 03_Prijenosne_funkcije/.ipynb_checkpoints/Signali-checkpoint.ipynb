# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt

# %%
def step(arr, t, v0, v1):
    return arr

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
# pts = [(t0, v0), (t1, v1)]
# pts = [(0,1), (1,5), (2, 0)]

def signal_from_points(t_arr, pts):
    y_arr = np.zeros(t_arr)
    if pts is None or len(pts)<1:
        return y_arr

    it = 0
    for p1, p2 in pairwise(pts):
        
        
        
    for i, t in t_arr:
        
        
        
        
        
    return t_arr


pts = [(0,0), (1,0), (1, 1), (2, 1), (2, 0), (3,0)]
t_arr = np.linspace(0,10, 100)
y = signal_from_points(t_arr, pts)

plt.figure()
plt.plot(t_arr, y)
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
max(t_arr)
# Out:
# 10.0

# %%
a[0]=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-f9da761c742a> in <module>()
# ----> 1 a[0]=1
#
# IndexError: too many indices for array
